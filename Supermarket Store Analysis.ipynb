# %%
# importing necessary libraries
import numpy as np
import pandas as pd

# for visuals
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Importing dataset
df = pd.read_csv(r'D:\Downloads\QA - TR PROJECT\Python Projects-20230906T192548Z-001\Python Projects\Stores.csv')
df
# Out:
#      Store ID   Store_Area  Items_Available  Daily_Customer_Count  Store_Sales
# 0            1        1659             1961                   530        66490
# 1            2        1461             1752                   210        39820
# 2            3        1340             1609                   720        54010
# 3            4        1451             1748                   620        53730
# 4            5        1770             2111                   450        46620
# ..         ...         ...              ...                   ...          ...
# 891        892        1582             1910                  1080        66390
# 892        893        1387             1663                   850        82080
# 893        894        1200             1436                  1060        76440
# 894        895        1299             1560                   770        96610
# 895        896        1174             1429                  1110        54340
#
# [896 rows x 5 columns]

# %% [markdown]
# # Data Inspection

# %%
df.head()
# Out:
#    Store ID   Store_Area  Items_Available  Daily_Customer_Count  Store_Sales
# 0          1        1659             1961                   530        66490
# 1          2        1461             1752                   210        39820
# 2          3        1340             1609                   720        54010
# 3          4        1451             1748                   620        53730
# 4          5        1770             2111                   450        46620

# %%
df.shape
# Out:
# (896, 5)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 896 entries, 0 to 895
# Data columns (total 5 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Store ID              896 non-null    int64
#  1   Store_Area            896 non-null    int64
#  2   Items_Available       896 non-null    int64
#  3   Daily_Customer_Count  896 non-null    int64
#  4   Store_Sales           896 non-null    int64
# dtypes: int64(5)
# memory usage: 35.1 KB

# %%
df.columns
# Out:
# Index(['Store ID ', 'Store_Area', 'Items_Available', 'Daily_Customer_Count',
#        'Store_Sales'],
#       dtype='object')

# %%
# Check for missing values
df.isnull().sum()
# Out:
# Store ID                0
# Store_Area              0
# Items_Available         0
# Daily_Customer_Count    0
# Store_Sales             0
# dtype: int64

# %%
# Check for duplicates
df.duplicated().value_counts()
# Out:
# False    896
# dtype: int64

# %%
df.describe()
# Out:
#         Store ID    Store_Area  Items_Available  Daily_Customer_Count  \
# count  896.000000   896.000000       896.000000            896.000000
# mean   448.500000  1485.409598      1782.035714            786.350446
# std    258.797218   250.237011       299.872053            265.389281
# min      1.000000   775.000000       932.000000             10.000000
# 25%    224.750000  1316.750000      1575.500000            600.000000
# 50%    448.500000  1477.000000      1773.500000            780.000000
# 75%    672.250000  1653.500000      1982.750000            970.000000
# max    896.000000  2229.000000      2667.000000           1560.000000
#
#          Store_Sales
# count     896.000000
# mean    59351.305804
# std     17190.741895
# min     14920.000000
# 25%     46530.000000
# 50%     58605.000000
# 75%     71872.500000
# max    116320.000000

# %% [markdown]
# ### Obersvation
# The data looks clean as there are no null values, no duplicates either

# %% [markdown]
# # Data Visualization

# %%
df.head()
# Out:
#    Store ID   Store_Area  Items_Available  Daily_Customer_Count  Store_Sales
# 0          1        1659             1961                   530        66490
# 1          2        1461             1752                   210        39820
# 2          3        1340             1609                   720        54010
# 3          4        1451             1748                   620        53730
# 4          5        1770             2111                   450        46620

# %%
# Sort the dataframe by 'Store_Sales' and take the top 5 areas
top_5_df = df.sort_values('Store_Sales', ascending=False).head(5)

# Bar chart (Top 5 Store Area by Store Sales)
top_5_df.plot.bar(x = 'Store_Area', y = 'Store_Sales', figsize=(10,6))

# label the axis
plt.xlabel('Store_Area')
plt.ylabel('Store_Sales')

# set the title
plt.title('Top 5 Store Area Vs Store Sales')

# show the visual
plt.show()

# %%
# Sort the dataframe by 'Items_Available' and take the top 5
top_5_df = df.sort_values('Items_Available', ascending=False).head(5)

# Creating a horizontal bar chart to visualize Items Available, Daily Customer Count and Store Sales for top 5
top_5_df[['Items_Available', 'Daily_Customer_Count', 'Store_Sales']].plot.barh(figsize=(10, 6))

# set the title
plt.title('Top 5 Items Available, Daily Customer Count, and Store Sales')

# show the visual
plt.show()

# %%
# Calculate correlations between variables
correlations = df.corr()
print(correlations)
# Out:
#                       Store ID   Store_Area  Items_Available  \
# Store ID               1.000000   -0.058705        -0.055707
# Store_Area            -0.058705    1.000000         0.998891
# Items_Available       -0.055707    0.998891         1.000000
# Daily_Customer_Count  -0.010029   -0.041423        -0.040978
# Store_Sales            0.071486    0.097474         0.098849
#
#                       Daily_Customer_Count  Store_Sales
# Store ID                         -0.010029     0.071486
# Store_Area                       -0.041423     0.097474
# Items_Available                  -0.040978     0.098849
# Daily_Customer_Count              1.000000     0.008629
# Store_Sales                       0.008629     1.000000

# %%
# Create a new figure for the heatmap with a size of 10x6
plt.figure(figsize=(10, 6))

# Generate a heatmap using seaborn to visualize the correlations between variables. 
# The 'annot' parameter is set to True to write the data value in each cell. 
# The colormap 'hot' is used to map normalized data values to colors.
sns.heatmap(correlations, annot=True, cmap='hot')

# Set the title of the heatmap
plt.title('Correlation Heatmap')

# Display the heatmap
plt.show()

# %%
# Sort the dataframe by 'Store_Sales' and take the top 5
top_5_df = df.sort_values('Store_Sales', ascending=False).head(5)

# Plot a Scatter plot for Store Sales by Items Available and Store Area for top 5
plt.scatter(top_5_df['Store_Area'], top_5_df['Items_Available'], c=top_5_df['Store_Sales'])

# Add labels and title
plt.xlabel('Store Area')
plt.ylabel('Items Available')
plt.colorbar(label='Store Sales')

# Show Plot
plt.show()

# %%
# Sort the dataframe by 'Items_Available' and take the top 10
top_10_df = df.sort_values('Items_Available', ascending=False).head(10)

# Plot scatter plot for top 10
top_10_df.plot.scatter('Items_Available', 'Store_Area', figsize=(10,6))

# Add labels and title
plt.xlabel('Items Available')
plt.ylabel('Store Area')
plt.title('Top 10 Store Area Vs Items Available')

# Show plot
plt.show()
